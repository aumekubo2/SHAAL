# %%
#bring dependencies
import pandas as pd
import requests
import json
from pprint import pprint
from prettytable import PrettyTable
from tqdm import tqdm
import matplotlib.pyplot as plt
from config import api_key_bls
from pandas import json_normalize

# %%
# The url for BLS API v2
url = 'https://api.bls.gov/publicAPI/v2/timeseries/data/'
key = '?registrationkey={}'.format(api_key_bls)
#series = Business Employment Dynamic, Local Area Unemployement Stats, and Mass Layoff Stats, Unemployment level, Labor Force level, CPI
headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['BDS0000000000000000110101LQ5','LAUCN281070000000003','MLUMS00NN0001003', 'LNS14000000', 'LNS13000000','CUUR0000SA0)'],
                   "startyear":"2010", "endyear":"2023",
                   'catalog': True,
                   'annualaverage':True,
                   "registrationkey": api_key_bls})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
p.status_code
# Out:
# 200

# %%
p.json()
# Out:
# {'status': 'REQUEST_SUCCEEDED',
#  'responseTime': 803,
#  'message': ['No Data Available for Series BDS0000000000000000110101LQ5 Year: 2023',
#   'No Data Available for Series MLUMS00NN0001003 Year: 2014',
#   'No Data Available for Series MLUMS00NN0001003 Year: 2015',
#   'No Data Available for Series MLUMS00NN0001003 Year: 2016',
#   'No Data Available for Series MLUMS00NN0001003 Year: 2017',
#   'No Data Available for Series MLUMS00NN0001003 Year: 2018',
#   'No Data Available for Series MLUMS00NN0001003 Year: 2019',
#   'No Data Available for Series MLUMS00NN0001003 Year: 2020',
#   'No Data Available for Series MLUMS00NN0001003 Year: 2021',
#   'No Data Available for Series MLUMS00NN0001003 Year: 2022',
#   'No Data Available for Series MLUMS00NN0001003 Year: 2023',
#   'Unable to get Catalog Data for series MLUMS00NN0001003',
#   'Series does not exist for Series CUUR0000SA0)'],
#  'Results': {'series': [{'seriesID': 'BDS0000000000000000110101LQ5',
#     'catalog': {'series_title': 'Gross job gains for firms with 1 to 4 employees (rounded to the nearest thousands)',
#      'series_id': 'BDS0000000000000000110101LQ5',
#      'seasonality': 'Seasonally Adjusted',
#      'survey_name': 'Business Employment Dynamics',
#      'survey_abbreviation': 'BD',
#      'measure_data_type': 'Gross Job Gains',
#      'commerce_industry': 'Total private',
#      'commerce_sector': 'Private Sector',
#      'area': 'U.S. totals'},
#     'data': [{'year': '2022',
#       'period': 'Q02',
#       'periodName': '2nd Quarter',
#       'latest': 'true',
#       'value': '955',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'Q01',
#       'periodName': '1st Quarter',
#       'value': '989',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'Q04',
#       'periodName': '4th Quarter',
#       'value': '1138',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'Q03',
#       'periodName': '3rd Quarter',
#       'value': '1064',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'Q02',
#       'periodName': '2nd Quarter',
#       'value': '999',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'Q01',
#       'periodName': '1st Quarter',
#       'value': '1116',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'Q04',
#       'periodName': '4th Quarter',
#       'value': '1098',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'Q03',
#       'periodName': '3rd Quarter',
#       'value': '1395',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'Q02',
#       'periodName': '2nd Quarter',
#       'value': '935',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'Q01',
#       'periodName': '1st Quarter',
#       'value': '967',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'Q04',
#       'periodName': '4th Quarter',
#       'value': '973',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'Q03',
#       'periodName': '3rd Quarter',
#       'value': '903',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'Q02',
#       'periodName': '2nd Quarter',
#       'value': '901',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'Q01',
#       'periodName': '1st Quarter',
#       'value': '954',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'Q04',
#       'periodName': '4th Quarter',
#       'value': '958',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'Q03',
#       'periodName': '3rd Quarter',
#       'value': '897',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'Q02',
#       'periodName': '2nd Quarter',
#       'value': '915',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'Q01',
#       'periodName': '1st Quarter',
#       'value': '955',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'Q04',
#       'periodName': '4th Quarter',
#       'value': '955',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'Q03',
#       'periodName': '3rd Quarter',
#       'value': '891',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'Q02',
#       'periodName': '2nd Quarter',
#       'value': '905',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'Q01',
#       'periodName': '1st Quarter',
#       'value': '957',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'Q04',
#       'periodName': '4th Quarter',
#       'value': '928',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'Q03',
#       'periodName': '3rd Quarter',
#       'value': '937',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'Q02',
#       'periodName': '2nd Quarter',
#       'value': '893',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'Q01',
#       'periodName': '1st Quarter',
#       'value': '916',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'Q04',
#       'periodName': '4th Quarter',
#       'value': '952',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'Q03',
#       'periodName': '3rd Quarter',
#       'value': '894',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'Q02',
#       'periodName': '2nd Quarter',
#       'value': '908',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'Q01',
#       'periodName': '1st Quarter',
#       'value': '922',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'Q04',
#       'periodName': '4th Quarter',
#       'value': '918',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'Q03',
#       'periodName': '3rd Quarter',
#       'value': '900',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'Q02',
#       'periodName': '2nd Quarter',
#       'value': '909',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'Q01',
#       'periodName': '1st Quarter',
#       'value': '903',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'Q04',
#       'periodName': '4th Quarter',
#       'value': '913',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'Q03',
#       'periodName': '3rd Quarter',
#       'value': '913',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'Q02',
#       'periodName': '2nd Quarter',
#       'value': '893',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'Q01',
#       'periodName': '1st Quarter',
#       'value': '905',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'Q04',
#       'periodName': '4th Quarter',
#       'value': '934',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'Q03',
#       'periodName': '3rd Quarter',
#       'value': '894',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'Q02',
#       'periodName': '2nd Quarter',
#       'value': '895',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'Q01',
#       'periodName': '1st Quarter',
#       'value': '948',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'Q04',
#       'periodName': '4th Quarter',
#       'value': '923',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'Q03',
#       'periodName': '3rd Quarter',
#       'value': '953',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'Q02',
#       'periodName': '2nd Quarter',
#       'value': '910',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'Q01',
#       'periodName': '1st Quarter',
#       'value': '904',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'Q04',
#       'periodName': '4th Quarter',
#       'value': '956',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'Q03',
#       'periodName': '3rd Quarter',
#       'value': '896',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'Q02',
#       'periodName': '2nd Quarter',
#       'value': '918',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'Q01',
#       'periodName': '1st Quarter',
#       'value': '877',
#       'footnotes': [{}]}]},
#    {'seriesID': 'LAUCN281070000000003',
#     'catalog': {'series_title': 'Unemployment Rate: Panola County, MS (U)',
#      'series_id': 'LAUCN281070000000003',
#      'seasonality': 'Not Seasonally Adjusted',
#      'survey_name': 'Local Area Unemployment Statistics',
#      'survey_abbreviation': 'LA',
#      'measure_data_type': 'unemployment rate',
#      'area': 'Panola County, MS',
#      'area_type': 'Counties and equivalents'},
#     'data': [{'year': '2023',
#       'period': 'M01',
#       'periodName': 'January',
#       'latest': 'true',
#       'value': '4.2',
#       'footnotes': [{'code': 'P', 'text': 'Preliminary.'}]},
#      {'year': '2022',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '4.0',
#       'footnotes': [{'code': 'P', 'text': 'Preliminary.'}]},
#      {'year': '2022',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '4.3',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '4.1',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '4.5',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '4.5',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '5.4',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '5.5',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '4.7',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '4.6',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '4.5',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '5.6',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '6.1',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M13',
#       'periodName': 'Annual',
#       'value': '7.1',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '4.5',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '4.6',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '5.3',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '5.9',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '7.0',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '7.8',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '8.8',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '7.8',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '7.5',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '8.3',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '8.6',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '8.9',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M13',
#       'periodName': 'Annual',
#       'value': '9.6',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '8.2',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '8.1',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '8.2',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '9.3',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '9.3',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '12.2',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '12.4',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '12.1',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '15.0',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '7.9',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '6.3',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '6.3',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M13',
#       'periodName': 'Annual',
#       'value': '6.6',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '5.8',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '6.0',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '5.9',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '6.2',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '7.1',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '8.1',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '8.1',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '6.4',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '6.0',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '6.5',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '6.4',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '6.7',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M13',
#       'periodName': 'Annual',
#       'value': '6.2',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '6.0',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '5.4',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '5.4',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '5.6',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '6.3',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '7.2',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '7.6',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '5.9',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '5.8',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '6.2',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '6.7',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '6.4',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M13',
#       'periodName': 'Annual',
#       'value': '6.9',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '5.8',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '5.9',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '6.1',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '6.7',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '7.0',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '8.3',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '8.4',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '7.4',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '6.7',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '6.4',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '6.6',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '7.5',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M13',
#       'periodName': 'Annual',
#       'value': '7.5',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '6.5',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '6.5',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '7.0',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '7.3',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '7.2',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '8.4',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '8.5',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '7.9',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '6.7',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '7.3',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '8.1',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '8.5',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M13',
#       'periodName': 'Annual',
#       'value': '8.8',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '8.2',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '7.8',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '7.9',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '7.9',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '8.1',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '9.5',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '9.7',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '9.8',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '8.2',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '8.7',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '9.4',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '10.4',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M13',
#       'periodName': 'Annual',
#       'value': '10.7',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '9.4',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '9.2',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '9.7',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '10.0',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '10.5',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '11.8',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '12.0',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '11.1',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '9.7',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '11.3',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '11.3',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '11.7',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M13',
#       'periodName': 'Annual',
#       'value': '11.9',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '10.4',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '10.7',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '11.6',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '11.3',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '12.0',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '12.4',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '13.3',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '12.3',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '11.4',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '11.7',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '12.1',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '12.9',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M13',
#       'periodName': 'Annual',
#       'value': '11.9',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '11.5',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '10.9',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '11.5',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '11.6',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '12.0',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '12.6',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '12.7',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '12.0',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '11.0',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '12.0',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '12.6',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '12.6',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M13',
#       'periodName': 'Annual',
#       'value': '12.9',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '12.4',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '12.2',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '12.7',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '13.0',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '13.3',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '14.0',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '14.1',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '13.1',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '12.3',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '12.4',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '12.7',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '12.7',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M13',
#       'periodName': 'Annual',
#       'value': '13.2',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '12.6',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '12.5',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '12.2',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '12.5',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '11.9',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '14.1',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '13.6',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '13.6',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '12.7',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '13.8',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '14.2',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '14.8',
#       'footnotes': [{}]}]},
#    {'seriesID': 'MLUMS00NN0001003',
#     'data': [{'year': '2013',
#       'period': 'M05',
#       'periodName': 'May',
#       'latest': 'true',
#       'value': '1383',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '1174',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '1132',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '960',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '1528',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M13',
#       'periodName': 'Annual',
#       'value': '17080',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '1973',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '2339',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '1142',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '811',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '1063',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '1515',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '1890',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '1201',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '1421',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '1125',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '895',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '1705',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M13',
#       'periodName': 'Annual',
#       'value': '18521',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '2433',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '1393',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '1101',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '1189',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '961',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '2176',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '1661',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '1367',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '1750',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '908',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '1024',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '2558',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M13',
#       'periodName': 'Annual',
#       'value': '19564',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '1931',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '1676',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '1642',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '920',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '976',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '2124',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '1861',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '1354',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '1840',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '1197',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '1183',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '2860',
#       'footnotes': [{}]}]},
#    {'seriesID': 'LNS14000000',
#     'catalog': {'series_title': '(Seas) Unemployment Rate',
#      'series_id': 'LNS14000000',
#      'seasonality': 'Seasonally Adjusted',
#      'survey_name': 'Labor Force Statistics from the Current Population Survey',
#      'survey_abbreviation': 'LN',
#      'measure_data_type': 'Percent or rate',
#      'commerce_industry': 'All Industries',
#      'occupation': 'All Occupations',
#      'cps_labor_force_status': 'Unemployment rate',
#      'demographic_age': '16 years and over',
#      'demographic_ethnic_origin': 'All Origins',
#      'demographic_race': 'All Races',
#      'demographic_gender': 'Both Sexes',
#      'demographic_education': 'All educational levels'},
#     'data': [{'year': '2023',
#       'period': 'M02',
#       'periodName': 'February',
#       'latest': 'true',
#       'value': '3.6',
#       'footnotes': [{}]},
#      {'year': '2023',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '3.4',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '3.5',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '3.6',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '3.7',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '3.5',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '3.7',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '3.5',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '3.6',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '3.6',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '3.6',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '3.6',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '3.8',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '4.0',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '3.9',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '4.2',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '4.5',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '4.8',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '5.2',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '5.4',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '5.9',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '5.8',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '6.1',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '6.1',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '6.2',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '6.3',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '6.7',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '6.7',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '6.9',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '7.9',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '8.4',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '10.2',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '11.0',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '13.2',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '14.7',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '4.4',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '3.5',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '3.5',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '3.6',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '3.6',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '3.6',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '3.5',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '3.7',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '3.7',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '3.6',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '3.7',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '3.6',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '3.8',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '3.8',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '4.0',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '3.9',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '3.8',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '3.8',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '3.7',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '3.8',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '3.8',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '4.0',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '3.8',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '4.0',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '4.0',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '4.1',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '4.0',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '4.1',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '4.2',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '4.2',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '4.3',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '4.4',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '4.3',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '4.3',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '4.4',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '4.4',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '4.4',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '4.6',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '4.7',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '4.7',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '4.7',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '4.9',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '5.0',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '4.9',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '4.8',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '4.9',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '4.8',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '5.1',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '5.0',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '4.9',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '4.8',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '5.0',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '5.1',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '5.0',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '5.0',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '5.1',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '5.2',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '5.3',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '5.6',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '5.4',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '5.4',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '5.5',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '5.7',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '5.6',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '5.8',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '5.7',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M09',
# ...
#      {'year': '2020',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '13521',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '16324',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '17624',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '20939',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '23050',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '7184',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '5708',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '5804',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '5870',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '5911',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '5957',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '5775',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '5981',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '6008',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '5909',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '5941',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '5911',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '6182',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '6115',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '6439',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '6389',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '6115',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '6211',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '6073',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '6156',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '6195',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '6447',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '6196',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '6459',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '6472',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '6581',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '6489',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '6632',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '6774',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '6700',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '6854',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '7082',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '6892',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '6873',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '7000',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '7089',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '7073',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '7379',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '7468',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '7521',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '7553',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '7811',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '7953',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '7784',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '7641',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '7744',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '7652',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '8067',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '7961',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '7702',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '7627',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '7907',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '8000',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '7922',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '7907',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '7992',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '8167',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '8247',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '8834',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '8550',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '8515',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '8599',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '8885',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '8717',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '9090',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '8990',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '9262',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '9599',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '9608',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '9460',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '9859',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '9702',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '10380',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '10349',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '10202',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '10404',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '10787',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '11136',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '11270',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '11279',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '11335',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '11751',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '11654',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '11760',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '11689',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '11950',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '12471',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '12298',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '12005',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '12124',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '12115',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '12471',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '12656',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '12692',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '12660',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '12646',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '12713',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '12813',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '12797',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '13093',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '13302',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '13594',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '13948',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '13818',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '13763',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '13962',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '13855',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '13957',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '13737',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '13820',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '14013',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '14348',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '15081',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '14516',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '14579',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '14648',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '14512',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '14474',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '14849',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '15325',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '15202',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '15113',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '15046',
#       'footnotes': [{}]}]},
#    {'seriesID': 'CUUR0000SA0)', 'data': []}]}}

# %%
json_data['Results']['series'][2]
# Out:
# {'seriesID': 'LNS13000000',
#  'catalog': {'series_title': '(Seas) Unemployment Level',
#   'series_id': 'LNS13000000',
#   'seasonality': 'Seasonally Adjusted',
#   'survey_name': 'Labor Force Statistics from the Current Population Survey',
#   'survey_abbreviation': 'LN',
#   'measure_data_type': 'Number in thousands',
#   'commerce_industry': 'All Industries',
#   'occupation': 'All Occupations',
#   'cps_labor_force_status': 'Unemployed',
#   'demographic_age': '16 years and over',
#   'demographic_ethnic_origin': 'All Origins',
#   'demographic_race': 'All Races',
#   'demographic_gender': 'Both Sexes',
#   'demographic_education': 'All educational levels'},
#  'data': [{'year': '2021',
#    'period': 'M12',
#    'periodName': 'December',
#    'value': '6329',
#    'footnotes': [{}]},
#   {'year': '2021',
#    'period': 'M11',
#    'periodName': 'November',
#    'value': '6780',
#    'footnotes': [{}]},
#   {'year': '2021',
#    'period': 'M10',
#    'periodName': 'October',
#    'value': '7345',
#    'footnotes': [{}]},
#   {'year': '2021',
#    'period': 'M09',
#    'periodName': 'September',
#    'value': '7677',
#    'footnotes': [{}]},
#   {'year': '2021',
#    'period': 'M08',
#    'periodName': 'August',
#    'value': '8324',
#    'footnotes': [{}]},
#   {'year': '2021',
#    'period': 'M07',
#    'periodName': 'July',
#    'value': '8704',
#    'footnotes': [{}]},
#   {'year': '2021',
#    'period': 'M06',
#    'periodName': 'June',
#    'value': '9508',
#    'footnotes': [{}]},
#   {'year': '2021',
#    'period': 'M05',
#    'periodName': 'May',
#    'value': '9257',
#    'footnotes': [{}]},
#   {'year': '2021',
#    'period': 'M04',
#    'periodName': 'April',
#    'value': '9737',
#    'footnotes': [{}]},
#   {'year': '2021',
#    'period': 'M03',
#    'periodName': 'March',
#    'value': '9712',
#    'footnotes': [{}]},
#   {'year': '2021',
#    'period': 'M02',
#    'periodName': 'February',
#    'value': '9982',
#    'footnotes': [{}]},
#   {'year': '2021',
#    'period': 'M01',
#    'periodName': 'January',
#    'value': '10155',
#    'footnotes': [{}]},
#   {'year': '2020',
#    'period': 'M12',
#    'periodName': 'December',
#    'value': '10795',
#    'footnotes': [{}]},
#   {'year': '2020',
#    'period': 'M11',
#    'periodName': 'November',
#    'value': '10760',
#    'footnotes': [{}]},
#   {'year': '2020',
#    'period': 'M10',
#    'periodName': 'October',
#    'value': '11090',
#    'footnotes': [{}]},
#   {'year': '2020',
#    'period': 'M09',
#    'periodName': 'September',
#    'value': '12599',
#    'footnotes': [{}]},
#   {'year': '2020',
#    'period': 'M08',
#    'periodName': 'August',
#    'value': '13521',
#    'footnotes': [{}]},
#   {'year': '2020',
#    'period': 'M07',
#    'periodName': 'July',
#    'value': '16324',
#    'footnotes': [{}]},
#   {'year': '2020',
#    'period': 'M06',
#    'periodName': 'June',
#    'value': '17624',
#    'footnotes': [{}]},
#   {'year': '2020',
#    'period': 'M05',
#    'periodName': 'May',
#    'value': '20939',
#    'footnotes': [{}]},
#   {'year': '2020',
#    'period': 'M04',
#    'periodName': 'April',
#    'value': '23050',
#    'footnotes': [{}]},
#   {'year': '2020',
#    'period': 'M03',
#    'periodName': 'March',
#    'value': '7184',
#    'footnotes': [{}]},
#   {'year': '2020',
#    'period': 'M02',
#    'periodName': 'February',
#    'value': '5708',
#    'footnotes': [{}]},
#   {'year': '2020',
#    'period': 'M01',
#    'periodName': 'January',
#    'value': '5804',
#    'footnotes': [{}]},
#   {'year': '2019',
#    'period': 'M12',
#    'periodName': 'December',
#    'value': '5870',
#    'footnotes': [{}]},
#   {'year': '2019',
#    'period': 'M11',
#    'periodName': 'November',
#    'value': '5911',
#    'footnotes': [{}]},
#   {'year': '2019',
#    'period': 'M10',
#    'periodName': 'October',
#    'value': '5957',
#    'footnotes': [{}]},
#   {'year': '2019',
#    'period': 'M09',
#    'periodName': 'September',
#    'value': '5775',
#    'footnotes': [{}]},
#   {'year': '2019',
#    'period': 'M08',
#    'periodName': 'August',
#    'value': '5981',
#    'footnotes': [{}]},
#   {'year': '2019',
#    'period': 'M07',
#    'periodName': 'July',
#    'value': '6008',
#    'footnotes': [{}]},
#   {'year': '2019',
#    'period': 'M06',
#    'periodName': 'June',
#    'value': '5909',
#    'footnotes': [{}]},
#   {'year': '2019',
#    'period': 'M05',
#    'periodName': 'May',
#    'value': '5941',
#    'footnotes': [{}]},
#   {'year': '2019',
#    'period': 'M04',
#    'periodName': 'April',
#    'value': '5911',
#    'footnotes': [{}]},
#   {'year': '2019',
#    'period': 'M03',
#    'periodName': 'March',
#    'value': '6182',
#    'footnotes': [{}]},
#   {'year': '2019',
#    'period': 'M02',
#    'periodName': 'February',
#    'value': '6115',
#    'footnotes': [{}]},
#   {'year': '2019',
#    'period': 'M01',
#    'periodName': 'January',
#    'value': '6439',
#    'footnotes': [{}]},
#   {'year': '2018',
#    'period': 'M12',
#    'periodName': 'December',
#    'value': '6389',
#    'footnotes': [{}]},
#   {'year': '2018',
#    'period': 'M11',
#    'periodName': 'November',
#    'value': '6115',
#    'footnotes': [{}]},
#   {'year': '2018',
#    'period': 'M10',
#    'periodName': 'October',
#    'value': '6211',
#    'footnotes': [{}]},
#   {'year': '2018',
#    'period': 'M09',
#    'periodName': 'September',
#    'value': '6073',
#    'footnotes': [{}]},
#   {'year': '2018',
#    'period': 'M08',
#    'periodName': 'August',
#    'value': '6156',
#    'footnotes': [{}]},
#   {'year': '2018',
#    'period': 'M07',
#    'periodName': 'July',
#    'value': '6195',
#    'footnotes': [{}]},
#   {'year': '2018',
#    'period': 'M06',
#    'periodName': 'June',
#    'value': '6447',
#    'footnotes': [{}]},
#   {'year': '2018',
#    'period': 'M05',
#    'periodName': 'May',
#    'value': '6196',
#    'footnotes': [{}]},
#   {'year': '2018',
#    'period': 'M04',
#    'periodName': 'April',
#    'value': '6459',
#    'footnotes': [{}]},
#   {'year': '2018',
#    'period': 'M03',
#    'periodName': 'March',
#    'value': '6472',
#    'footnotes': [{}]},
#   {'year': '2018',
#    'period': 'M02',
#    'periodName': 'February',
#    'value': '6581',
#    'footnotes': [{}]},
#   {'year': '2018',
#    'period': 'M01',
#    'periodName': 'January',
#    'value': '6489',
#    'footnotes': [{}]},
#   {'year': '2017',
#    'period': 'M12',
#    'periodName': 'December',
#    'value': '6632',
#    'footnotes': [{}]},
#   {'year': '2017',
#    'period': 'M11',
#    'periodName': 'November',
#    'value': '6774',
#    'footnotes': [{}]},
#   {'year': '2017',
#    'period': 'M10',
#    'periodName': 'October',
#    'value': '6700',
#    'footnotes': [{}]},
#   {'year': '2017',
#    'period': 'M09',
#    'periodName': 'September',
#    'value': '6854',
#    'footnotes': [{}]},
#   {'year': '2017',
#    'period': 'M08',
#    'periodName': 'August',
#    'value': '7082',
#    'footnotes': [{}]},
#   {'year': '2017',
#    'period': 'M07',
#    'periodName': 'July',
#    'value': '6892',
#    'footnotes': [{}]},
#   {'year': '2017',
#    'period': 'M06',
#    'periodName': 'June',
#    'value': '6873',
#    'footnotes': [{}]},
#   {'year': '2017',
#    'period': 'M05',
#    'periodName': 'May',
#    'value': '7000',
#    'footnotes': [{}]},
#   {'year': '2017',
#    'period': 'M04',
#    'periodName': 'April',
#    'value': '7089',
#    'footnotes': [{}]},
#   {'year': '2017',
#    'period': 'M03',
#    'periodName': 'March',
#    'value': '7073',
#    'footnotes': [{}]},
#   {'year': '2017',
#    'period': 'M02',
#    'periodName': 'February',
#    'value': '7379',
#    'footnotes': [{}]},
#   {'year': '2017',
#    'period': 'M01',
#    'periodName': 'January',
#    'value': '7468',
#    'footnotes': [{}]},
#   {'year': '2016',
#    'period': 'M12',
#    'periodName': 'December',
#    'value': '7521',
#    'footnotes': [{}]},
#   {'year': '2016',
#    'period': 'M11',
#    'periodName': 'November',
#    'value': '7553',
#    'footnotes': [{}]},
#   {'year': '2016',
#    'period': 'M10',
#    'periodName': 'October',
#    'value': '7811',
#    'footnotes': [{}]},
#   {'year': '2016',
#    'period': 'M09',
#    'periodName': 'September',
#    'value': '7953',
#    'footnotes': [{}]},
#   {'year': '2016',
#    'period': 'M08',
#    'periodName': 'August',
#    'value': '7784',
#    'footnotes': [{}]},
#   {'year': '2016',
#    'period': 'M07',
#    'periodName': 'July',
#    'value': '7641',
#    'footnotes': [{}]},
#   {'year': '2016',
#    'period': 'M06',
#    'periodName': 'June',
#    'value': '7744',
#    'footnotes': [{}]},
#   {'year': '2016',
#    'period': 'M05',
#    'periodName': 'May',
#    'value': '7652',
#    'footnotes': [{}]},
#   {'year': '2016',
#    'period': 'M04',
#    'periodName': 'April',
#    'value': '8067',
#    'footnotes': [{}]},
#   {'year': '2016',
#    'period': 'M03',
#    'periodName': 'March',
#    'value': '7961',
#    'footnotes': [{}]},
#   {'year': '2016',
#    'period': 'M02',
#    'periodName': 'February',
#    'value': '7702',
#    'footnotes': [{}]},
#   {'year': '2016',
#    'period': 'M01',
#    'periodName': 'January',
#    'value': '7627',
#    'footnotes': [{}]},
#   {'year': '2015',
#    'period': 'M12',
#    'periodName': 'December',
#    'value': '7907',
#    'footnotes': [{}]},
#   {'year': '2015',
#    'period': 'M11',
#    'periodName': 'November',
#    'value': '8000',
#    'footnotes': [{}]},
#   {'year': '2015',
#    'period': 'M10',
#    'periodName': 'October',
#    'value': '7922',
#    'footnotes': [{}]},
#   {'year': '2015',
#    'period': 'M09',
#    'periodName': 'September',
#    'value': '7907',
#    'footnotes': [{}]},
#   {'year': '2015',
#    'period': 'M08',
#    'periodName': 'August',
#    'value': '7992',
#    'footnotes': [{}]},
#   {'year': '2015',
#    'period': 'M07',
#    'periodName': 'July',
#    'value': '8167',
#    'footnotes': [{}]},
#   {'year': '2015',
#    'period': 'M06',
#    'periodName': 'June',
#    'value': '8247',
#    'footnotes': [{}]},
#   {'year': '2015',
#    'period': 'M05',
#    'periodName': 'May',
#    'value': '8834',
#    'footnotes': [{}]},
#   {'year': '2015',
#    'period': 'M04',
#    'periodName': 'April',
#    'value': '8550',
#    'footnotes': [{}]},
#   {'year': '2015',
#    'period': 'M03',
#    'periodName': 'March',
#    'value': '8515',
#    'footnotes': [{}]},
#   {'year': '2015',
#    'period': 'M02',
#    'periodName': 'February',
#    'value': '8599',
#    'footnotes': [{}]},
#   {'year': '2015',
#    'period': 'M01',
#    'periodName': 'January',
#    'value': '8885',
#    'footnotes': [{}]},
#   {'year': '2014',
#    'period': 'M12',
#    'periodName': 'December',
#    'value': '8717',
#    'footnotes': [{}]},
#   {'year': '2014',
#    'period': 'M11',
#    'periodName': 'November',
#    'value': '9090',
#    'footnotes': [{}]},
#   {'year': '2014',
#    'period': 'M10',
#    'periodName': 'October',
#    'value': '8990',
#    'footnotes': [{}]},
#   {'year': '2014',
#    'period': 'M09',
#    'periodName': 'September',
#    'value': '9262',
#    'footnotes': [{}]},
#   {'year': '2014',
#    'period': 'M08',
#    'periodName': 'August',
#    'value': '9599',
#    'footnotes': [{}]},
#   {'year': '2014',
#    'period': 'M07',
#    'periodName': 'July',
#    'value': '9608',
#    'footnotes': [{}]},
#   {'year': '2014',
#    'period': 'M06',
#    'periodName': 'June',
#    'value': '9460',
#    'footnotes': [{}]},
#   {'year': '2014',
#    'period': 'M05',
#    'periodName': 'May',
#    'value': '9859',
#    'footnotes': [{}]},
#   {'year': '2014',
#    'period': 'M04',
#    'periodName': 'April',
#    'value': '9702',
#    'footnotes': [{}]},
#   {'year': '2014',
#    'period': 'M03',
#    'periodName': 'March',
#    'value': '10380',
#    'footnotes': [{}]},
#   {'year': '2014',
#    'period': 'M02',
#    'periodName': 'February',
#    'value': '10349',
#    'footnotes': [{}]},
#   {'year': '2014',
#    'period': 'M01',
#    'periodName': 'January',
#    'value': '10202',
#    'footnotes': [{}]},
#   {'year': '2013',
#    'period': 'M12',
#    'periodName': 'December',
#    'value': '10404',
#    'footnotes': [{}]},
#   {'year': '2013',
#    'period': 'M11',
#    'periodName': 'November',
#    'value': '10787',
#    'footnotes': [{}]},
#   {'year': '2013',
#    'period': 'M10',
#    'periodName': 'October',
#    'value': '11136',
#    'footnotes': [{}]},
#   {'year': '2013',
#    'period': 'M09',
#    'periodName': 'September',
#    'value': '11270',
#    'footnotes': [{}]},
#   {'year': '2013',
#    'period': 'M08',
#    'periodName': 'August',
#    'value': '11279',
#    'footnotes': [{}]},
#   {'year': '2013',
#    'period': 'M07',
#    'periodName': 'July',
#    'value': '11335',
#    'footnotes': [{}]},
#   {'year': '2013',
#    'period': 'M06',
#    'periodName': 'June',
#    'value': '11751',
#    'footnotes': [{}]},
#   {'year': '2013',
#    'period': 'M05',
#    'periodName': 'May',
#    'value': '11654',
#    'footnotes': [{}]},
#   {'year': '2013',
#    'period': 'M04',
#    'periodName': 'April',
#    'value': '11760',
#    'footnotes': [{}]},
#   {'year': '2013',
#    'period': 'M03',
#    'periodName': 'March',
#    'value': '11689',
#    'footnotes': [{}]},
#   {'year': '2013',
#    'period': 'M02',
#    'periodName': 'February',
#    'value': '11950',
#    'footnotes': [{}]},
#   {'year': '2013',
#    'period': 'M01',
#    'periodName': 'January',
#    'value': '12471',
#    'footnotes': [{}]},
#   {'year': '2012',
#    'period': 'M12',
#    'periodName': 'December',
#    'value': '12298',
#    'footnotes': [{}]},
#   {'year': '2012',
#    'period': 'M11',
#    'periodName': 'November',
#    'value': '12005',
#    'footnotes': [{}]},
#   {'year': '2012',
#    'period': 'M10',
#    'periodName': 'October',
#    'value': '12124',
#    'footnotes': [{}]},
#   {'year': '2012',
#    'period': 'M09',
#    'periodName': 'September',
#    'value': '12115',
#    'footnotes': [{}]},
#   {'year': '2012',
#    'period': 'M08',
#    'periodName': 'August',
#    'value': '12471',
#    'footnotes': [{}]},
#   {'year': '2012',
#    'period': 'M07',
#    'periodName': 'July',
#    'value': '12656',
#    'footnotes': [{}]},
#   {'year': '2012',
#    'period': 'M06',
#    'periodName': 'June',
#    'value': '12692',
#    'footnotes': [{}]},
#   {'year': '2012',
#    'period': 'M05',
#    'periodName': 'May',
#    'value': '12660',
#    'footnotes': [{}]},
#   {'year': '2012',
#    'period': 'M04',
#    'periodName': 'April',
#    'value': '12646',
#    'footnotes': [{}]},
#   {'year': '2012',
#    'period': 'M03',
#    'periodName': 'March',
#    'value': '12713',
#    'footnotes': [{}]},
#   {'year': '2012',
#    'period': 'M02',
#    'periodName': 'February',
#    'value': '12813',
#    'footnotes': [{}]},
#   {'year': '2012',
#    'period': 'M01',
#    'periodName': 'January',
#    'value': '12797',
#    'footnotes': [{}]},
#   {'year': '2011',
#    'period': 'M12',
#    'periodName': 'December',
#    'value': '13093',
#    'footnotes': [{}]},
#   {'year': '2011',
#    'period': 'M11',
#    'periodName': 'November',
#    'value': '13302',
#    'footnotes': [{}]},
#   {'year': '2011',
#    'period': 'M10',
#    'periodName': 'October',
#    'value': '13594',
#    'footnotes': [{}]},
#   {'year': '2011',
#    'period': 'M09',
#    'periodName': 'September',
#    'value': '13948',
#    'footnotes': [{}]},
#   {'year': '2011',
#    'period': 'M08',
#    'periodName': 'August',
#    'value': '13818',
#    'footnotes': [{}]},
#   {'year': '2011',
#    'period': 'M07',
#    'periodName': 'July',
#    'value': '13763',
#    'footnotes': [{}]},
#   {'year': '2011',
#    'period': 'M06',
#    'periodName': 'June',
#    'value': '13962',
#    'footnotes': [{}]},
#   {'year': '2011',
#    'period': 'M05',
#    'periodName': 'May',
#    'value': '13855',
#    'footnotes': [{}]},
#   {'year': '2011',
#    'period': 'M04',
#    'periodName': 'April',
#    'value': '13957',
#    'footnotes': [{}]},
#   {'year': '2011',
#    'period': 'M03',
#    'periodName': 'March',
#    'value': '13737',
#    'footnotes': [{}]},
#   {'year': '2011',
#    'period': 'M02',
#    'periodName': 'February',
#    'value': '13820',
#    'footnotes': [{}]},
#   {'year': '2011',
#    'period': 'M01',
#    'periodName': 'January',
#    'value': '14013',
#    'footnotes': [{}]},
#   {'year': '2010',
#    'period': 'M12',
#    'periodName': 'December',
#    'value': '14348',
#    'footnotes': [{}]},
#   {'year': '2010',
#    'period': 'M11',
#    'periodName': 'November',
#    'value': '15081',
#    'footnotes': [{}]},
#   {'year': '2010',
#    'period': 'M10',
#    'periodName': 'October',
#    'value': '14516',
#    'footnotes': [{}]},
#   {'year': '2010',
#    'period': 'M09',
#    'periodName': 'September',
#    'value': '14579',
#    'footnotes': [{}]},
#   {'year': '2010',
#    'period': 'M08',
#    'periodName': 'August',
#    'value': '14648',
#    'footnotes': [{}]},
#   {'year': '2010',
#    'period': 'M07',
#    'periodName': 'July',
#    'value': '14512',
#    'footnotes': [{}]},
#   {'year': '2010',
#    'period': 'M06',
#    'periodName': 'June',
#    'value': '14474',
#    'footnotes': [{}]},
#   {'year': '2010',
#    'period': 'M05',
#    'periodName': 'May',
#    'value': '14849',
#    'footnotes': [{}]},
#   {'year': '2010',
#    'period': 'M04',
#    'periodName': 'April',
#    'value': '15325',
#    'footnotes': [{}]},
#   {'year': '2010',
#    'period': 'M03',
#    'periodName': 'March',
#    'value': '15202',
#    'footnotes': [{}]},
#   {'year': '2010',
#    'period': 'M02',
#    'periodName': 'February',
#    'value': '15113',
#    'footnotes': [{}]},
#   {'year': '2010',
#    'period': 'M01',
#    'periodName': 'January',
#    'value': '15046',
#    'footnotes': [{}]}]}

# %%
#saving it to the csv file LAUCN281070000000003

# %%
import requests
import json
import pandas as pd


data_url = 'https://api.bls.gov/publicAPI/v2/timeseries/data/'
api_key = '1315085c23bf46318cdba4ea8abfbfaf'

#series ID for LAUCN281070000000003
series_id = 'LAUCN281070000000003'

#request parameters for the API
data = json.dumps({"seriesid": [series_id], "startyear":"2010", "endyear":"2023",
                   "registrationkey": api_key})
headers = {'Content-type': 'application/json'}

# Send the POST request to the API endpoint and retrieve the data
response = requests.post(data_url, data=data, headers=headers)
json_data = json.loads(response.text)
results = json_data['Results']['series'][0]['data']

#DataFrame and set the index to the date
df = pd.DataFrame(results)
df['value'] = pd.to_numeric(df['value'])
df['date'] = pd.to_datetime(df['year'] + '-' + df['period'])
df = df.set_index('date')
df = df[['value']]

# Save the DataFrame to a CSV file
df.to_csv('LAUCN281070000000003.csv')

# %%
 
#error on getting csv file from #BDS0000000000000000110101LQ

# %%
#looping through each series and saving it to the different csv file

# %%
import requests
import json
import pandas as pd

# Set the API endpoint and API key
data_url = 'https://api.bls.gov/publicAPI/v2/timeseries/data/'
api_key = '1315085c23bf46318cdba4ea8abfbfaf'

# series IDs
series_ids = ['MLUMS00NN0001003', 'LNS14000000', 'LNS13000000']

# Set the request parameters for the API
start_year = '2010'
end_year = '2023'
data = json.dumps({"startyear": start_year, "endyear": end_year, "registrationkey": api_key})
headers = {'Content-type': 'application/json'}

# Loop over each series ID, retrieve the data, and save it to a separate CSV file
for series_id in series_ids:
    # request parameters for the API
    data = json.dumps({"seriesid": [series_id], "startyear": start_year, "endyear": end_year,
                       "registrationkey": api_key})
    
    # Send the POST request to the API endpoint and retrieve the data
    response = requests.post(data_url, data=data, headers=headers)
    json_data = json.loads(response.text)
    results = json_data['Results']['series'][0]['data']

    # Convert Pandas DataFrame and set the index to the date
    df = pd.DataFrame(results)
    df['value'] = pd.to_numeric(df['value'])
    df['date'] = pd.to_datetime(df['year'] + '-' + df['period'])
    df = df.set_index('date')
    df = df[['value']]

    # Save the DataFrame csv
    file_name = series_id + '.csv'
    df.to_csv(file_name)

# %%
#series ids from BLS

#'BDS0000000000000000110001LQ5',#Business Employment Dynamic - jobs Gain
#'BDS0000000000000000110004LQ5',#Business Employment Dynamic - jobs loss
#'BDS0000000000000000120001LQ5',#Business Employment Dynamic - stablishment gain
#'BDS0000000000000000120004LQ5',#Business Employment Dynamic - stablishment loss
 #'SMU19197802023800001', # State and Area Employment, Hrs, Earnings
#'NCU5306633300003', #National Compensation - Discontinued Series (SIC and Census of Population)
 #'LAUCN281070000000003', #Local Area Unemployement Stats
 #'JLU00000000HIL', #Job Openings and Labor Turnover Survey (SIC basis)
#'MLUMS00NN0001003', #Mass Layoff Stats
#'CUUR0000SA0', # Consumer Price Index
 #'LNS14000000', #unemployment leval
 #'LNS13000000', #labor force leval

# %%
list_columns= []
for series in json_data['Results']['series']:
#     x=pd.DataFrame(columns=["series title","series id","seasonality","survey_name","measure_data_type","commerce_industy","commerce_sector",])
    seriesId = series['seriesID']
    print(seriesId)
    if 'catalog' in series.keys():
        seasonality = series['catalog']['seasonality']
        survey_name = series['catalog']['survey_name']
        measure_data_type = series['catalog']['measure_data_type']
        if 'commerce_industry' in series['catalog'].keys():
            commerce_industry = series['catalog']['commerce_industry']
        else:
            commerce_industry = None
        if 'commerce_sector' in series['catalog'].keys():
            commerce_sector = series['catalog']['commerce_sector']
        else:
            commerce_sector = None
        if 'area' in series['catalog'].keys():
            area = series['catalog']['area']
        else:
            area = None
       # area= series['catalog']['area']
    else:
        seasonality = None
        survey_name = None
        measure_data_type = None
        commerce_industry = None
        commerce_sector = None
        area= None
    #add all variables & create a list to append to the list above
    for item in series['data']:
        year = item['year']
        period = item['period']
        periodName = item['periodName']
        value = item['value']
        list_columns.append([seriesId,seasonality,survey_name,measure_data_type,
                             commerce_industry,commerce_sector,area,year,period,periodName,value])
column= pd.DataFrame(list_columns,columns=['seriesId','seasonality','survey_name','measure_data_type',
                             'commerce_industry','commerce_sector','area','year','period','periodName','value'])
column.head()
#         footnotes=""
#         for footnote in item['footnotes']:
#             if footnote:
#                 footnotes = footnotes + footnote['text'] + ','
#         if 'M01' <= period <= 'M12':
#            x.add_row([seriesId,year,period,value,footnotes[0:-1]])
#     output = open(seriesId + '.txt','w')
#     output.write (x.get_string())
#     output.close()
# Out:
# CUUR0000SA0
# LNS14000000
# LNS13000000
# MLUMS00NN0001003
# BDS0000000000000000110101LQ5
# LAUCN281070000000003
#       seriesId              seasonality                          survey_name  \
# 0  CUUR0000SA0  Not Seasonally Adjusted  CPI for All Urban Consumers (CPI-U)
# 1  CUUR0000SA0  Not Seasonally Adjusted  CPI for All Urban Consumers (CPI-U)
# 2  CUUR0000SA0  Not Seasonally Adjusted  CPI for All Urban Consumers (CPI-U)
# 3  CUUR0000SA0  Not Seasonally Adjusted  CPI for All Urban Consumers (CPI-U)
# 4  CUUR0000SA0  Not Seasonally Adjusted  CPI for All Urban Consumers (CPI-U)
#
#   measure_data_type commerce_industry commerce_sector               area  \
# 0         All items              None            None  U.S. city average
# 1         All items              None            None  U.S. city average
# 2         All items              None            None  U.S. city average
# 3         All items              None            None  U.S. city average
# 4         All items              None            None  U.S. city average
#
#    year period periodName    value
# 0  2021    M13     Annual  270.970
# 1  2021    M12   December  278.802
# 2  2021    M11   November  277.948
# 3  2021    M10    October  276.589
# 4  2021    M09  September  274.310

# %%
#series ids
#getting response from BLS

# %%
#series
headers = {'Content-type': 'application/json'} #contains info about the message- such as destination
# Submit the list of series as data - payload actual data being transmitted over a network
data = json.dumps({"seriesid": ['BDS0000000000000000110001LQ5',#Business Employment Dynamic - jobs Gain
                                'BDS0000000000000000110004LQ5',#Business Employment Dynamic - jobs loss
                                'BDS0000000000000000120001LQ5',#Business Employment Dynamic - stablishment gain
                                 'BDS0000000000000000120004LQ5',#Business Employment Dynamic - stablishment loss
                                'SMU19197802023800001', # State and Area Employment, Hrs, Earnings
                                'NCU5306633300003', #National Compensation - Discontinued Series (SIC and Census of Population)
                                'LAUCN281070000000003', #Local Area Unemployement Stats
                                'JLU00000000HIL', #Job Openings and Labor Turnover Survey (SIC basis)
                                #'MLUMS00NN0001003', #Mass Layoff Stats
                                'CUUR0000SA0', # Consumer Price Index
                                'LNS14000000', #unemployment leval
                                'LNS13000000', #labor force leval
                               ],
                   'startyear':'2010', 'endyear':'2023',
                   'catalog':True,
                   'annualaverage':True,
                   "registrationkey": api_key_bls}, indent=4)
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
p.status_code
# Out:
# 200

# %%
#2023 doesnt have enough dataset to show. dataset time period up until 2010-2022

# %%
#here created dataframe including all the seriesids and only showing year, period and value

# %%
import requests
import json
import pandas as pd

# Set the API endpoint and API key
data_url = 'https://api.bls.gov/publicAPI/v2/timeseries/data/'
api_key = '1315085c23bf46318cdba4ea8abfbfaf'

# Set request headers and data
headers = {'Content-type': 'application/json'}

#create empty DataFrame
series_ids = ['BDS0000000000000000120004LQ5','BDS0000000000000000110001LQ5','BDS0000000000000000110004LQ5','BDS0000000000000000120001LQ5','SMU19197802023800001', 'NCU5306633300003', 'LAUCN281070000000003', 'JLU00000000HIL', 'LNS14000000', 'LNS13000000', 'CUUR0000SA0']
df = pd.DataFrame(columns=['series_id', 'year', 'period', 'value'])

# Loop through series IDs and make API request
for series_id in series_ids:
    data = json.dumps({
        "seriesid": [series_id],
        "startyear": "2010",
        "endyear": "2023",
        "registrationkey": api_key
    })
    response = requests.post(data_url, headers=headers, data=data)
    json_data = json.loads(response.text)
    
    # Extract data for series and append to DataFrame
    series_data = json_data['Results']['series'][0]['data']
    df_temp = pd.DataFrame(series_data, columns=['year', 'period', 'value'])
    df_temp['series_id'] = series_id
    df = pd.concat([df, df_temp])

# Reset index and print
df.reset_index(drop=True, inplace=True)
print(df.head())
print(df.tail(10))
# Out:
#                       series_id  year period value
# 0  BDS0000000000000000120004LQ5  2022    Q02  2345
# 1  BDS0000000000000000120004LQ5  2022    Q01  2072
# 2  BDS0000000000000000120004LQ5  2021    Q04  2030
# 3  BDS0000000000000000120004LQ5  2021    Q03  2127
# 4  BDS0000000000000000120004LQ5  2021    Q02  2063
#        series_id  year period    value
# 978  CUUR0000SA0  2010    M10  218.711
# 979  CUUR0000SA0  2010    M09  218.439
# 980  CUUR0000SA0  2010    M08  218.312
# 981  CUUR0000SA0  2010    M07  218.011
# 982  CUUR0000SA0  2010    M06  217.965
# 983  CUUR0000SA0  2010    M05  218.178
# 984  CUUR0000SA0  2010    M04  218.009
# 985  CUUR0000SA0  2010    M03  217.631
# 986  CUUR0000SA0  2010    M02  216.741
# 987  CUUR0000SA0  2010    M01  216.687

# %%
#'BDS0000000000000000110001LQ5',#Business Employment Dynamic - jobs Gain
#'BDS0000000000000000110004LQ5',#Business Employment Dynamic - jobs loss
#'BDS0000000000000000120001LQ5',#Business Employment Dynamic - stablishment gain
#'BDS0000000000000000120004LQ5',#Business Employment Dynamic - stablishment loss
 #'SMU19197802023800001', # State and Area Employment, Hrs, Earnings
#'NCU5306633300003', #National Compensation - Discontinued Series (SIC and Census of Population)
 #'LAUCN281070000000003', #Local Area Unemployement Stats
 #'JLU00000000HIL', #Job Openings and Labor Turnover Survey (SIC basis)
#'MLUMS00NN0001003', #Mass Layoff Stats
#'CUUR0000SA0', # Consumer Price Index
 #'LNS14000000', #unemployment leval
 #'LNS13000000', #labor force leval

# %%
#retrieving quarterly gross job gains for the total private sector in U.S

# %%
# Set the API endpoint and API key
data_url = 'https://api.bls.gov/publicAPI/v2/timeseries/data/'
api_key = '1315085c23bf46318cdba4ea8abfbfaf'
headers = {'Content-type': 'application/json'} #contains info about the message- such as destination
# Submit the list of series as data - payload actual data being transmitted over a network
data = json.dumps({"seriesid": ['BDS0000000000000000110001LQ5'],
                   'startyear':'2010', 'endyear':'2023',
                   'catalog':True,
                   'annualaverage':True,
                   "registrationkey": api_key}, indent=4)
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)

# Create a pandas DataFrame from the results
df = pd.DataFrame(json_data['Results'], columns=json_data['Results'][0].keys())
df['date'] = pd.to_datetime(df['year'] + 'Q' + df['qtr'])
df['datavalue'] = pd.to_numeric(df['datavalue'])


# Plot the data
fig = px.line(df, x='date', y='datavalue')
fig.update_traces(mode='lines+markers', hovertemplate='Quarter=%{x}<br>Gross Job Gains=%{y:.0f}<extra></extra>')
fig.update_layout(title='Gross Job Gains for the Total Private Sector in the U.S.',
                  xaxis_title='Quarter', yaxis_title='Gross Job Gains', hovermode='x')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/kl/m0y8txln53774pt40hp8gplr0000gn/T/ipykernel_936/896472620.py in <module>
#      13
#      14 # Create a pandas DataFrame from the results
# ---> 15 df = pd.DataFrame(json_data['Results'], columns=json_data['Results'][0].keys())
#      16 df['date'] = pd.to_datetime(df['year'] + 'Q' + df['qtr'])
#      17 df['datavalue'] = pd.to_numeric(df['datavalue'])
#
# KeyError: 0

# %%
# Set the API endpoint and API key
data_url = 'https://api.bls.gov/publicAPI/v2/timeseries/data/'
api_key = '1315085c23bf46318cdba4ea8abfbfaf'

# Set request headers and data
headers = {'Content-type': 'application/json'}

#create empty DataFrame
series_ids = ['BDS0000000000000000110001LQ5','BDS0000000000000000110004LQ5']
df = pd.DataFrame(columns=['series_id', 'year', 'period', 'value'])

# Loop through series IDs and make API requests
df = pd.DataFrame()
for series_id in series_ids:
    data = json.dumps({
        "get": "year,periodemp,empflag,data_type_code",
        "for": "us:*",
        "filter": f"series_id eq '{series_id}'",
        "key": api_key
    })
    response = requests.post(data_url, headers=headers, data=data)
    json_data = json.loads(response.text)
    results = json_data['Results']
    df_temp = pd.DataFrame(results, columns=json_data['Results'][0].keys())
    df_temp['measure_data_type'] = df_temp['data_type_code'].map({
        'JG': 'Job Gains',
        'JL': 'Job Losses'
    })
    df = pd.concat([df, df_temp])


# Convert the year and period columns to datetime
df['year'] = pd.to_datetime(df['year'], format='%Y')
df['periodemp'] = pd.to_datetime(df['periodemp'], format='%m')

# Pivot the DataFrame to wide format
df_pivot = df.pivot_table(index=['year', 'periodemp'], columns='measure_data_type', values='value', aggfunc='sum').reset_index()

# Add a column for the total net change in jobs
df_pivot['Net Change'] = df_pivot['Job Gains'] - df_pivot['Job Losses']

# Create the line chart
fig = px.line(df_pivot, x='year', y='Net Change')
fig.update_traces(mode='lines+markers', hovertemplate='Year=%{x}<br>Net Change=%{y:.0f}<extra></extra>')
fig.update_layout(title='Net Change in Jobs for the Total Private Sector in the U.S.',
                  xaxis_title='Year', yaxis_title='Net Change in Jobs', hovermode='x')

# Show the chart
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/kl/m0y8txln53774pt40hp8gplr0000gn/T/ipykernel_936/569371091.py in <module>
#      22     json_data = json.loads(response.text)
#      23     results = json_data['Results']
# ---> 24     df_temp = pd.DataFrame(results, columns=json_data['Results'][0].keys())
#      25     df_temp['measure_data_type'] = df_temp['data_type_code'].map({
#      26         'JG': 'Job Gains',
#
# KeyError: 0

# %%
#NAICS10: Total private industry
#23: Construction
#48-49: Transportation and warehousing
#62: Health care and social assistance

# %%
# API endpoint
url ='https://api.bls.gov/publicAPI/v2/timeseries/data/'

# API key
api_key = '1315085c23bf46318cdba4ea8abfbfaf'

# Start and end year
start_year = '2010'
end_year = '2023'

# Setting the industry codes for the data we want to retrieve
industry_codes = ['NAICS10', '23', '48-49', '62']

# Request parameters
data = json.dumps({
    "seriesid": [],
    "startyear": start_year,
    "endyear": end_year,
    "catalog": "true",
    "registrationkey": api_key,
    "industrycode": industry_codes
})

# Request headers
headers = {'Content-type': 'application/json'}

# Retrieve the data
response = requests.post(url, data=data, headers=headers)
json_data = json.loads(response.text)
print(response)
# Out:
# <Response [200]>

# %%
#analyzing CPI data and NAICS10 data for any correlation

# %%
# Set the API endpoint and API key
data_url = 'https://api.bls.gov/publicAPI/v2/timeseries/data/'
api_key = '1315085c23bf46318cdba4ea8abfbfaf'

# Set request headers and data for CPI
headers_cpi = {'Content-type': 'application/json'}
data_cpi = json.dumps({
    "seriesid": ["CUUR0000SA0"],
    "startyear": "2010",
    "endyear": "2023",
    "registrationkey": api_key
})
response_cpi = requests.post(data_url, headers=headers_cpi, data=data_cpi)
json_data_cpi = json.loads(response_cpi.text)

# Set request headers and data for NAICS 10
headers_naics10 = {'Content-type': 'application/json'}
data_naics10 = json.dumps({
    "seriesid": ["ENU0423200510"], #seriesid for NAICS10 sector employment
    "startyear": "2010",
    "endyear": "2023",
    "registrationkey": api_key
})
response_naics10 = requests.post(data_url, headers=headers_naics10, data=data_naics10)
json_data_naics10 = json.loads(response_naics10.text)

# Extract data for CPI and NAICS 10
cpi_data = json_data_cpi['Results']['series'][0]['data']
naics10_data = json_data_naics10['Results']['series'][0]['data']

# Create DataFrames for CPI and NAICS 10
df_cpi = pd.DataFrame(cpi_data, columns=['year', 'period', 'value_cpi'])
df_naics10 = pd.DataFrame(naics10_data, columns=['year', 'period', 'value_naics10'])

# Merge DataFrames
df_merged = pd.merge(df_cpi, df_naics10, on=['year', 'period'])

# Convert data types
df_merged['value_cpi'] = pd.to_numeric(df_merged['value_cpi'])
df_merged['value_naics10'] = pd.to_numeric(df_merged['value_naics10'])

# Create scatter plot of CPI and NAICS 10
plt.scatter(df_merged['value_cpi'], df_merged['value_naics10'])
plt.xlabel('CPI')
plt.ylabel('NAICS 10 Employment')
plt.title('Correlation between CPI and NAICS 10 Employment')
plt.figure(figsize=(8,6))

plt.show()
plt.show()

# %%
#calculating the correlation coefficient between NAICS 10 employment and CPI

# Set the API endpoint and API key
data_url = 'https://api.bls.gov/publicAPI/v2/timeseries/data/'
api_key = '1315085c23bf46318cdba4ea8abfbfaf'

# Set request headers and data for CPI
headers_cpi = {'Content-type': 'application/json'}
data_cpi = json.dumps({
    "seriesid": ["CUUR0000SA0"],
    "startyear": "2010",
    "endyear": "2023",
    "registrationkey": api_key
})
response_cpi = requests.post(data_url, headers=headers_cpi, data=data_cpi)
json_data_cpi = json.loads(response_cpi.text)

# Set request headers and data for NAICS 10
headers_naics10 = {'Content-type': 'application/json'}
data_naics10 = json.dumps({
    "seriesid": ["ENU0423200510"], #seriesid for NAICS10 sector employment
    "startyear": "2010",
    "endyear": "2023",
    "registrationkey": api_key
})
response_naics10 = requests.post(data_url, headers=headers_naics10, data=data_naics10)
json_data_naics10 = json.loads(response_naics10.text)

# Extract data for CPI and NAICS 10
cpi_data = json_data_cpi['Results']['series'][0]['data']
naics10_data = json_data_naics10['Results']['series'][0]['data']

# Create DataFrames for CPI and NAICS 10
df_cpi = pd.DataFrame(cpi_data, columns=['year', 'period', 'value_cpi'])
df_naics10 = pd.DataFrame(naics10_data, columns=['year', 'period', 'value_naics10'])

# Merge DataFrames
df_merged = pd.merge(df_cpi, df_naics10, on=['year', 'period'])

# Convert data types
df_merged['value_cpi'] = pd.to_numeric(df_merged['value_cpi'])
df_merged['value_naics10'] = pd.to_numeric(df_merged['value_naics10'])

# Calculate correlation coefficient
corr_coeff = df_merged['value_cpi'].corr(df_merged['value_naics10'])
print('Correlation Coefficient: ', corr_coeff)
# Out:
# Correlation Coefficient:  nan

# %%
#calculating regression analysis to estimate the relationship between NAICS 10 employment and CPI
