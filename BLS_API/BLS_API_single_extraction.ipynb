# %%
import requests
import json
import prettytable
headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['CEU5051800001'],"startyear":"2013", "endyear":"2023"})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
for series in json_data['Results']['series']: 
    x=prettytable.PrettyTable(["series id","year","period","value","footnotes"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        footnotes=""
        for footnote in item['footnotes']:
            if footnote:
                footnotes = footnotes + footnote['text'] + ','
        if 'M01' <= period <= 'M12':
            x.add_row([seriesId,year,period,value,footnotes[0:-1]])
    output = open(seriesId + '.txt','w')
    output.write (x.get_string())
    output.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/sg/g_kx7jjs4rs267h1_s2r64b40000gn/T/ipykernel_58693/3642820220.py in <module>
#      22     output.write (x.get_string())
#      23     output.close()
# ---> 24     output.to_csv("tech_employees.csv", index=False, encoding="ISO-8859-1")
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'to_csv'

# %%
print(item)
# Out:
# {'year': '2013', 'period': 'M01', 'periodName': 'January', 'value': '35', 'footnotes': [{}]}

# %%
#GGUQO100000000000050010L

# %%
import requests
import json
import prettytable
headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['CEU0800000001'],"startyear":"2013", "endyear":"2023"})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
for series in json_data['Results']['series']:
    x=prettytable.PrettyTable(["series id","year","period","value","footnotes"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        footnotes=""
        for footnote in item['footnotes']:
            if footnote:
                footnotes = footnotes + footnote['text'] + ','
        if 'M01' <= period <= 'M12':
            x.add_row([seriesId,year,period,value,footnotes[0:-1]])
    output = open(seriesId + '.txt','w')
    output.write (x.get_string())
    output.close()

# %%
json_data
# Out:
# {'status': 'REQUEST_SUCCEEDED',
#  'responseTime': 223,
#  'message': ['Year range has been reduced to the system-allowed limit of 10 years.'],
#  'Results': {'series': [{'seriesID': 'CEU0800000003',
#     'data': [{'year': '2022',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '32.77',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '32.62',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '32.81',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '32.40',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '32.16',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '32.10',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '31.84',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '32.18',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '32.00',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '31.77',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '31.69',
#       'footnotes': [{}]},
#      {'year': '2022',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '31.95',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '31.23',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '31.04',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '30.99',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '30.78',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '30.71',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '30.36',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '30.15',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '30.44',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '30.21',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '29.95',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '30.08',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '29.99',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '29.71',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '29.65',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '29.32',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '29.29',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '29.35',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '29.03',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '28.94',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '29.54',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '30.08',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '28.73',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '28.63',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '28.34',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '28.26',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '28.01',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '27.93',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '28.07',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '27.68',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '27.58',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '27.66',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '27.53',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '27.63',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '27.57',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '27.58',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '27.51',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '27.44',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '27.09',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '27.04',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '27.21',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '26.71',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '26.82',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '26.48',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '26.62',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '26.91',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '26.60',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '26.58',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '26.60',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '26.26',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '26.17',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '26.34',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '26.15',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '25.84',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '26.03',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '25.70',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '25.83',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '26.16',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '25.86',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '25.91',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '26.06',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '25.54',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '25.54',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '25.73',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '25.41',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '25.17',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '25.18',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '25.08',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '25.39',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '25.30',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '25.21',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '25.23',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '25.25',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '24.89',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '25.11',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '24.85',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '24.76',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '24.74',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '24.51',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '24.47',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '24.59',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '24.67',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '24.79',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '24.82',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '24.61',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '24.27',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '24.52',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '24.21',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '24.19',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '23.99',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '23.97',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '24.13',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '24.00',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '24.10',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '24.23',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '24.32',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '24.06',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '23.99',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '23.81',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '23.74',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '23.89',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '23.47',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '23.49',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '23.65',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '23.50',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '23.65',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '23.57',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '23.65',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '23.62',
#       'footnotes': [{}]}]}]}}
